# %%
import yt

# %%
ds = yt.load("single_level/plt0000000//")
# Out:
# yt : [INFO     ] 2019-05-09 22:10:05,514 Parameters: current_time              = 0.0
# yt : [INFO     ] 2019-05-09 22:10:05,515 Parameters: domain_dimensions         = [64 64  1]
# yt : [INFO     ] 2019-05-09 22:10:05,516 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2019-05-09 22:10:05,516 Parameters: domain_right_edge         = [1. 1. 1.]

# %%
#ds.field_list  # lists the variables in the plot file

# %%
var = "rho"

# %%
p = yt.SlicePlot(ds, "z", var)
p.set_log(var, False)
# Out:
# yt : [INFO     ] 2019-05-09 22:10:42,752 xlim = 0.000000 1.000000
# yt : [INFO     ] 2019-05-09 22:10:42,753 ylim = 0.000000 1.000000
# yt : [INFO     ] 2019-05-09 22:10:42,755 xlim = 0.000000 1.000000
# yt : [INFO     ] 2019-05-09 22:10:42,756 ylim = 0.000000 1.000000
# yt : [INFO     ] 2019-05-09 22:10:42,758 Making a fixed resolution buffer of (('boxlib', 'rho')) 800 by 800
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
plot = yt.LinePlot(ds,var,[0.5,0,0],[.5,1,0],64)
plot.set_log(var,False)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
