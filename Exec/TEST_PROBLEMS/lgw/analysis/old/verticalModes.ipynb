# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [10, 5]
import yt
##yt.mylog.setLevel()
yt.utilities.logger.disable_stream_logging()

# %% [markdown]
# # Purely vertical modes
#
# setup with kh=0, kv =/ 0
#
# summary: basically, because of how MAESTROeX sets up the problem, you can't actually do this.
#
# the problem setup is to set a *conceptual* "base state", then "perturb it" to make the (*actual*) full state, but the code actually sets the base state after that by averaging the full state. Thus, any such code will just be averaged out and it will be subsumed into the background

# %%
dataDir="../oldruns/fri14/kh0//"

# %%
ds = yt.load(dataDir+"/plt0000000/")
var = "rhopert";
plot = yt.SlicePlot(ds, "z", var);
plot.set_log(var, False);
plot.show()
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
