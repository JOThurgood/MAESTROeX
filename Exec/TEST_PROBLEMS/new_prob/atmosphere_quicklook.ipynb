# %%
import yt

# %% [markdown]
# ## Line plots of p0 and rho0

# %%
ds = yt.load("single_level/plt0000091/") # I'd love a way to make this quiet
ds.field_list # list params
# Out:
# yt : [INFO     ] 2019-05-14 10:40:33,882 Parameters: current_time              = 1000.0
# yt : [INFO     ] 2019-05-14 10:40:33,883 Parameters: domain_dimensions         = [64 64  1]
# yt : [INFO     ] 2019-05-14 10:40:33,885 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2019-05-14 10:40:33,886 Parameters: domain_right_edge         = [1.e+09 1.e+09 1.e+00]
# [('boxlib', 'Hnuc'),
#  ('boxlib', 'MachNumber'),
#  ('boxlib', 'Pi'),
#  ('boxlib', 'S'),
#  ('boxlib', 'X(A)'),
#  ('boxlib', 'abar'),
#  ('boxlib', 'conductivity'),
#  ('boxlib', 'deltaT'),
#  ('boxlib', 'deltagamma'),
#  ('boxlib', 'deltap'),
#  ('boxlib', 'divw0'),
#  ('boxlib', 'entropy'),
#  ('boxlib', 'entropypert'),
#  ('boxlib', 'gpix'),
#  ('boxlib', 'gpiy'),
#  ('boxlib', 'h'),
#  ('boxlib', 'h0'),
#  ('boxlib', 'magvel'),
#  ('boxlib', 'momentum'),
#  ('boxlib', 'omegadot(A)'),
#  ('boxlib', 'p0'),
#  ('boxlib', 'p0pluspi'),
#  ('boxlib', 'pioverp0'),
#  ('boxlib', 'rho'),
#  ('boxlib', 'rho0'),
#  ('boxlib', 'rhoX(A)'),
#  ('boxlib', 'rhoh'),
#  ('boxlib', 'rhoh0'),
#  ('boxlib', 'rhohpert'),
#  ('boxlib', 'rhopert'),
#  ('boxlib', 'tfromh'),
#  ('boxlib', 'tfromp'),
#  ('boxlib', 'thermal'),
#  ('boxlib', 'tpert'),
#  ('boxlib', 'velx'),
#  ('boxlib', 'vely'),
#  ('boxlib', 'vort'),
#  ('boxlib', 'w0x'),
#  ('boxlib', 'w0y')]

# %%
var = "p0"
plot = yt.LinePlot(ds,var,[0.,0.,0],[0.,1e9,0],64)
plot.set_log(var, False)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
#plot.save("p0.png")

# %%
var = "rho0"
plot = yt.LinePlot(ds,var,[0,0,0],[0,1e9,0],64)
plot.set_log(var, False)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
#plot.save("rho0.png")

# %% [markdown]
# ## 2d coloured contour of rho
# (if rho is uniform it will draw something wierd)
# (yt also decides to automatically make up a unit that is not meaningful...)

# %%
var = "rhopert";
plot = yt.SlicePlot(ds, "z", var);
plot.set_log(var, False);
plot
# Out:
# yt : [INFO     ] 2019-05-14 10:40:37,214 xlim = 0.000000 1000000000.000000
# yt : [INFO     ] 2019-05-14 10:40:37,215 ylim = 0.000000 1000000000.000000
# yt : [INFO     ] 2019-05-14 10:40:37,217 xlim = 0.000000 1000000000.000000
# yt : [INFO     ] 2019-05-14 10:40:37,217 ylim = 0.000000 1000000000.000000
# yt : [INFO     ] 2019-05-14 10:40:37,219 Making a fixed resolution buffer of (('boxlib', 'rhopert')) 800 by 800
# yt : [WARNING  ] 2019-05-14 10:40:37,253 Plot image for field ('boxlib', 'rhopert') has both positive and negative values. Min = -0.008374, Max = 0.022010.
# yt : [WARNING  ] 2019-05-14 10:40:37,254 Switching to symlog colorbar scaling unless linear scaling is specified later
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
var = "rho"
plot = yt.LinePlot(ds,var,[0.,0.,0],[1e9,0.,0],64)
plot.set_log(var, False)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
