# %%
import yt

# %% [markdown]
# ## Line plots of p0 and rho0

# %%
ds = yt.load("single_level/plt_InitData///") # I'd love a way to make this quiet
# ds.field_list # list params
# Out:
# yt : [INFO     ] 2019-05-10 11:25:10,499 Parameters: current_time              = 0.0
# yt : [INFO     ] 2019-05-10 11:25:10,499 Parameters: domain_dimensions         = [64 64  1]
# yt : [INFO     ] 2019-05-10 11:25:10,500 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2019-05-10 11:25:10,500 Parameters: domain_right_edge         = [1. 1. 1.]

# %%
var = "p0"
plot = yt.LinePlot(ds,var,[0.5,0,0],[.5,1,0],64)
plot.set_log(var, False)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
var = "rho0"
plot = yt.LinePlot(ds,var,[0.5,0,0],[.5,1,0],64)
plot.set_log(var, False)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %% [markdown]
# ## 2d coloured contour of rho
# (if rho is uniform it will draw something wierd)
# (yt also decides to automatically make up a unit that is not meaningful...)

# %%
var = "rho";
plot = yt.SlicePlot(ds, "z", var);
plot.set_log(var, False);
plot
# Out:
# yt : [INFO     ] 2019-05-10 11:25:11,064 xlim = 0.000000 1.000000
# yt : [INFO     ] 2019-05-10 11:25:11,065 ylim = 0.000000 1.000000
# yt : [INFO     ] 2019-05-10 11:25:11,066 xlim = 0.000000 1.000000
# yt : [INFO     ] 2019-05-10 11:25:11,067 ylim = 0.000000 1.000000
# yt : [INFO     ] 2019-05-10 11:25:11,068 Making a fixed resolution buffer of (('boxlib', 'rho')) 800 by 800
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
var = "rho"
plot = yt.LinePlot(ds,var,[0.,0.,0],[1.,0.,0],64)
plot.set_log(var, False)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
